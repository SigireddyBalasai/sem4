# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Iris.csv')
df.hist()
plt.rcParams['figure.figsize'] = [30,20]
plt.show()

# %%
df.plot(kind='density',subplots=True,layout=(3,3),sharex=False)
# plt.rcParams['figure.figsize'] = [30,30]
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(3,3),sharex=False,sharey=False)
plt.show()

# %%
corr = df.corr(method='pearson')
corr
# Out:
# <ipython-input-39-fd1764de5e1e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr(method='pearson')
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_17960_row0_col0, #T_17960_row1_col1, #T_17960_row2_col2, #T_17960_row3_col3, #T_17960_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_17960_row0_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_17960_row0_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_17960_row0_col3, #T_17960_row3_col0 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_17960_row0_col4, #T_17960_row4_col0 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_17960_row1_col0 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_17960_row1_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_17960_row1_col3 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_17960_row1_col4 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_17960_row2_col0, #T_17960_row2_col1, #T_17960_row2_col3, #T_17960_row2_col4, #T_17960_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_17960_row3_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_17960_row3_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_17960_row4_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_17960_row4_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_17960_row4_col3 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_17960" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17960_level0_col0" class="col_heading level0 col0" >Id</th>
#       <th id="T_17960_level0_col1" class="col_heading level0 col1" >SepalLengthCm</th>
#       <th id="T_17960_level0_col2" class="col_heading level0 col2" >SepalWidthCm</th>
#       <th id="T_17960_level0_col3" class="col_heading level0 col3" >PetalLengthCm</th>
#       <th id="T_17960_level0_col4" class="col_heading level0 col4" >PetalWidthCm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17960_level0_row0" class="row_heading level0 row0" >Id</th>
#       <td id="T_17960_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_17960_row0_col1" class="data row0 col1" >0.716676</td>
#       <td id="T_17960_row0_col2" class="data row0 col2" >-0.397729</td>
#       <td id="T_17960_row0_col3" class="data row0 col3" >0.882747</td>
#       <td id="T_17960_row0_col4" class="data row0 col4" >0.899759</td>
#     </tr>
#     <tr>
#       <th id="T_17960_level0_row1" class="row_heading level0 row1" >SepalLengthCm</th>
#       <td id="T_17960_row1_col0" class="data row1 col0" >0.716676</td>
#       <td id="T_17960_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_17960_row1_col2" class="data row1 col2" >-0.109369</td>
#       <td id="T_17960_row1_col3" class="data row1 col3" >0.871754</td>
#       <td id="T_17960_row1_col4" class="data row1 col4" >0.817954</td>
#     </tr>
#     <tr>
#       <th id="T_17960_level0_row2" class="row_heading level0 row2" >SepalWidthCm</th>
#       <td id="T_17960_row2_col0" class="data row2 col0" >-0.397729</td>
#       <td id="T_17960_row2_col1" class="data row2 col1" >-0.109369</td>
#       <td id="T_17960_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_17960_row2_col3" class="data row2 col3" >-0.420516</td>
#       <td id="T_17960_row2_col4" class="data row2 col4" >-0.356544</td>
#     </tr>
#     <tr>
#       <th id="T_17960_level0_row3" class="row_heading level0 row3" >PetalLengthCm</th>
#       <td id="T_17960_row3_col0" class="data row3 col0" >0.882747</td>
#       <td id="T_17960_row3_col1" class="data row3 col1" >0.871754</td>
#       <td id="T_17960_row3_col2" class="data row3 col2" >-0.420516</td>
#       <td id="T_17960_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_17960_row3_col4" class="data row3 col4" >0.962757</td>
#     </tr>
#     <tr>
#       <th id="T_17960_level0_row4" class="row_heading level0 row4" >PetalWidthCm</th>
#       <td id="T_17960_row4_col0" class="data row4 col0" >0.899759</td>
#       <td id="T_17960_row4_col1" class="data row4 col1" >0.817954</td>
#       <td id="T_17960_row4_col2" class="data row4 col2" >-0.356544</td>
#       <td id="T_17960_row4_col3" class="data row4 col3" >0.962757</td>
#       <td id="T_17960_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df)
plt.show()
